# %% [markdown]
# # Matplotlib göz atma

# %% [markdown]
# # plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(1,10,0.1)
y=np.sin(x)

plt.plot(x,y)

plt.title("sin grafiği")
plt.xlabel("x ekseni")
plt.ylabel("y ekseni")

plt.show()

# %% [markdown]
# # scatter

# %%
x=np.random.rand(100)
y=np.random.rand(100)

color=np.random.rand(100)
size=np.random.randint(50,150,10)

plt.scatter(x,y,c="red")

plt.show()

# %%
x=np.random.rand(1000)
y=np.random.rand(1000)

color=np.random.rand(1000)
size=np.random.randint(1,100,1000)

plt.scatter(x,y,c=color,s=size)

plt.title("point chart")
plt.xlabel("x axis")
plt.ylabel("y axisis")
plt.show()

# %% [markdown]
# # Hist

# %%
data=np.random.rand(100)

plt.hist(data, bins=30)

plt.title("histogram")
plt.xlabel("values")
plt.ylabel("frequency")
plt.show()

# %% [markdown]
# # Pie

# %%
secim={"rte":12,
        "K.K":5,
        "ince":30,
        "super 6":8,
        "necmiye":45}

plt.pie(secim.values())

plt.title("2023 secim sonucalri")
plt.show()

# %% [markdown]
# # 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

x=np.arange(1,10,1)
y=np.arange(1,10,1)
x,y =np.meshgrid(x,y)
r=np.sqrt(x**2+y**2)
z=np.cos(r)

fig=plt.figure()
ax=fig.add_subplot(111,projection="3d")

ax.set_xlabel("x ekseni")
ax.set_ylabel("y ekseni")
ax.set_zlabel("z ekseni")
ax.plot_surface(x,y,z)
plt.show()
